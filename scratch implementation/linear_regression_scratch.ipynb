# %%
import numpy as np

# %%
#Linear regression
class LinearRegression:
    def __init__(self,learning_rate=0.01,n_iter=1000):
        self.bias = None
        self.weights= None
        self.lr = learning_rate
        self.n_iter= n_iter

    def fit(self,X,y):
        m,n = X.shape #(no of samples,no of features)
        # step 1 -initialise
        self.bias = 0
        self.weights = np.zeros(n)

        # Gradient descent
        for i in range(self.n_iter):
            #step2 - calc y_pred
            y_pred = self.bias + np.dot(X, self.weights)

            #step 3- calc gradient
            db = (1/m) * np.sum(y_pred - y)
            dw = (1/m) * np.dot(X.T,(y_pred-y))

            # step 4 - convergence theorem
            self.bias = self.bias - self.lr * db
            self.weights = self.weights - self.lr * dw
        

    def predict(self,X):
        y_pred = self.bias + np.dot(X, self.weights)
        return y_pred

# %%
X=np.array([[1],[2],[3],[4],[5]])
y=np.array([2,4,6,8,10])

model = LinearRegression()
model.fit(X,y)

y_pred=model.predict(X)
print(y_pred)
# Out:
# [2.06850809 4.04226297 6.01601785 7.98977273 9.96352761]

# %%
class LinearRegressionOLS:
    def __init__(self):
        self.bias=None
        self.weights=None
        
    def fit(self,X,y):
        m=X.shape
        X_b = np.c_[np.ones((m,1)),X]

        theta=np.dot(np.linalg.inv(X_b.T,X_b),np.dot(X_b.T,y))

        self.bias = theta[0]
        self.weights = theta[1:]



    def predict(self,X):
        y_pred=self.bias + np.dot(X,self.weights)
        return y_pred

# %%
X=np.array([[1],[2],[3],[4],[5]])
y=np.array([2,4,6,8,10])

model = LinearRegressionOLS()
model.fit(X,y)

y_pred=model.predict(X)
print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       2 y=np.array([2,4,6,8,10])
#       4 model = LinearRegressionOLS()
# ----> 5 model.fit(X,y)
#       7 y_pred=model.predict(X)
#       8 print(y_pred)
#
# Cell In[15], line 8, in LinearRegressionOLS.fit(self, X, y)
#       6 def fit(self,X,y):
#       7     m=X.shape
# ----> 8     X_b = np.c_[np.ones((m,1)),X]
#      10     theta=np.dot(np.linalg.inv(X_b.T,X_b),np.dot(X_b.T,y))
#      12     self.bias = theta[0]
#
# File ~/anaconda3/lib/python3.13/site-packages/numpy/_core/numeric.py:233, in ones(shape, dtype, order, device, like)
#     228 if like is not None:
#     229     return _ones_with_like(
#     230         like, shape, dtype=dtype, order=order, device=device
#     231     )
# --> 233 a = empty(shape, dtype, order, device=device)
#     234 multiarray.copyto(a, 1, casting='unsafe')
#     235 return a
#
# TypeError: 'tuple' object cannot be interpreted as an integer
